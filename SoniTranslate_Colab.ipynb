# %% [markdown]
# <a href="https://colab.research.google.com/github/catpal912/NotionNext/blob/main/SoniTranslate_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SoniTranslate
#
# | Description | Link |
# | ----------- | ---- |
# | 🎉 Repository | [![GitHub Repository](https://img.shields.io/badge/GitHub-Repository-black?style=flat-square&logo=github)](https://github.com/R3gm/SoniTranslate/) |
# | 🚀 Online Demo in HF | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/r3gm/SoniTranslate_translate_audio_of_a_video_content) |

# %%
# @title Install requirements for SoniTranslate
# !git clone https://github.com/r3gm/SoniTranslate.git
# %cd SoniTranslate

# !pip uninstall chex pandas-stubs ibis-framework albumentations albucore -y -q
# !python -m pip install -q pip==23.1.2
# !apt install git-lfs
# !git lfs install

# !sed -i 's|git+https://github.com/R3gm/whisperX.git@cuda_11_8|git+https://github.com/R3gm/whisperX.git@cuda_12_x|' requirements_base.txt
# !pip install -q -r requirements_base.txt
# !pip install -q -r requirements_extra.txt
# !pip install -q ort-nightly-gpu --index-url=https://aiinfra.pkgs.visualstudio.com/PublicPackages/_packaging/ort-cuda-12-nightly/pypi/simple/

Install_PIPER_TTS = True # @param {type:"boolean"}

if Install_PIPER_TTS:
    # !pip install -q piper-tts==1.2.0

Install_Coqui_XTTS = True # @param {type:"boolean"}

if Install_Coqui_XTTS:
    # !pip install -q -r requirements_xtts.txt
    # !pip install -q TTS==0.21.1  --no-deps
# Out:
# Cloning into 'SoniTranslate'...
# remote: Enumerating objects: 1179, done.
# remote: Counting objects: 100% (411/411), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 1179 (delta 332), reused 312 (delta 269), pack-reused 768 (from 1)
# Receiving objects: 100% (1179/1179), 20.06 MiB | 10.02 MiB/s, done.
# Resolving deltas: 100% (799/799), done.
# /content/SoniTranslate
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.7 MB/s eta 0:00:00
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Updated git hooks.
# Git LFS initialized.
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 63.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 23.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 13.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 105.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 108.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 21.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 109.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 106.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 107.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 108.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 104.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 34.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 105.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 107.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 108.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 96.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 103.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 82.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 65.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 212.3 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 20.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.2/807.2 kB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.6/890.6 kB 59.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.8/362.8 kB 38.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 88.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 61.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 35.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 100.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 77.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 64.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# WARNING: typer 0.12.5 does not provide the extra 'all'
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 50.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 108.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 108.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 82.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 71.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 118.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 84.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 22.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 115.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 119.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 119.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 78.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 45.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 24.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 109.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 108.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 49.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 116.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 118.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 111.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 118.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.2/233.2 kB 25.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 52.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.3 MB/s eta 0:00:00
#   Building wheel for pyannote.audio (setup.py) ... done
#   Building wheel for whisperx (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 90.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 25.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 62.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 MB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 76.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.7/422.7 kB 38.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 89.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 35.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 52.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.3/278.3 kB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 44.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.4/112.4 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.8 MB/s eta 0:00:00
#   Building wheel for pyworld (pyproject.toml) ... done
#   Building wheel for fairseq (pyproject.toml) ... done
#   Building wheel for srt (setup.py) ... done
#   Building wheel for openvoice (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.3/202.3 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 43.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 51.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/51.2 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 834.7/834.7 kB 53.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 94.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 27.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 35.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 35.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 45.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 87.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 17.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 18.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 82.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 MB 9.6 MB/s eta 0:00:00
#   Building wheel for bnnumerizer (setup.py) ... done
#   Building wheel for encodec (setup.py) ... done
#   Building wheel for gruut-ipa (setup.py) ... done
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Building wheel for gruut (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.22.0 requires ibis-framework[bigquery]<=9.2.0,>=9.0.0, which is not installed.
# optax 0.2.3 requires chex>=0.1.86, which is not installed.
# bigframes 1.22.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# jax 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# jaxlib 0.4.33 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
# nx-cugraph-cu12 24.10.0 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# xarray 2024.9.0 requires numpy>=1.24, but you have numpy 1.23.5 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 933.3/933.3 kB 19.2 MB/s eta 0:00:00

# %% [markdown]
# One important step is to accept the license agreement for using Pyannote. You need to have an account on Hugging Face and `accept the license to use the models`: https://huggingface.co/pyannote/speaker-diarization and https://huggingface.co/pyannote/segmentation
#
# Get your KEY TOKEN here: https://hf.co/settings/tokens
#
# When you are creating the new Access Token in Hugging Face, make sure to tick "Read access to contents of all public gated repos you can access".

# %%
#@markdown # `RUN THE WEB APP`
YOUR_HF_TOKEN = "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" #@param {type:'string'}
# %env YOUR_HF_TOKEN={YOUR_HF_TOKEN}
theme = "Taithrah/Minimal" # @param ["Taithrah/Minimal", "aliabid94/new-theme", "gstaff/xkcd", "ParityError/LimeFace", "abidlabs/pakistan", "rottenlittlecreature/Moon_Goblin", "ysharma/llamas", "gradio/dracula_revamped"]
interface_language = "chinese_zh_cn" # @param ['arabic', 'azerbaijani', 'chinese_zh_cn', 'english', 'french', 'german', 'hindi', 'indonesian', 'italian', 'japanese', 'korean', 'marathi', 'polish', 'portuguese', 'russian', 'spanish', 'swedish', 'turkish', 'ukrainian', 'vietnamese']
verbosity_level = "info" # @param ["debug", "info", "warning", "error", "critical"]


# %cd /content/SoniTranslate
# !python app_rvc.py --theme {theme} --verbosity_level {verbosity_level} --language {interface_language} --public_url
# Out:
# env: YOUR_HF_TOKEN=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
# /content/SoniTranslate
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR-MDX-NET-Voc_FT.onnx" to /content/SoniTranslate/mdx_models/UVR-MDX-NET-Voc_FT.onnx
#
# 100% 63.7M/63.7M [00:01<00:00, 41.6MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR_MDXNET_KARA_2.onnx" to /content/SoniTranslate/mdx_models/UVR_MDXNET_KARA_2.onnx
#
# 100% 50.3M/50.3M [00:01<00:00, 41.9MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/Reverb_HQ_By_FoxJoy.onnx" to /content/SoniTranslate/mdx_models/Reverb_HQ_By_FoxJoy.onnx
#
# 100% 63.7M/63.7M [00:01<00:00, 51.6MB/s]
# [INFO] >> Downloading: "https://github.com/TRvlvr/model_repo/releases/download/all_public_uvr_models/UVR-MDX-NET-Inst_HQ_4.onnx" to /content/SoniTranslate/mdx_models/UVR-MDX-NET-Inst_HQ_4.onnx
#
# 100% 56.3M/56.3M [00:01<00:00, 45.9MB/s]
# [INFO] >> PIPER TTS enabled
# [INFO] >> Coqui XTTS enabled
# [INFO] >> In this app, by using Coqui TTS (text-to-speech), you acknowledge and agree to the license.
# You confirm that you have read, understood, and agreed to the Terms and Conditions specified at the following link:
# https://coqui.ai/cpml.txt.
# [INFO] >> Downloading: "https://huggingface.co/rhasspy/piper-voices/resolve/main/voices.json" to /content/SoniTranslate/PIPER_MODELS/voices.json
#
# 100% 187k/187k [00:00<00:00, 36.1MB/s]
# [INFO] >> Working in: cuda
# themes/theme_schema@0.0.1.json: 100% 16.8k/16.8k [00:00<00:00, 56.9MB/s]
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 4.19.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://a102e7d4f5edbda577.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# [INFO] >> Content in 'outputs' removed.
# [INFO] >> Cache flushed
# [INFO] >> Processing video...
# [INFO] >> Video codec: h264
# [INFO] >> Process video...
# [INFO] >> Process audio...
# [INFO] >> Transcribing...
# vocabulary.json:   0% 0.00/1.07M [00:00<?, ?B/s]
# config.json: 100% 2.39k/2.39k [00:00<00:00, 18.9MB/s]
#
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 3.17MB/s]
#
# model.bin:   0% 0.00/3.09G [00:00<?, ?B/s]
#
# tokenizer.json:   0% 0.00/2.48M [00:00<?, ?B/s]
# model.bin:   0% 10.5M/3.09G [00:00<01:26, 35.5MB/s]
# model.bin:   1% 21.0M/3.09G [00:00<01:16, 39.9MB/s]
# vocabulary.json: 100% 1.07M/1.07M [00:00<00:00, 1.28MB/s]
#
# model.bin:   1% 41.9M/3.09G [00:01<01:11, 42.4MB/s]
# model.bin:   2% 52.4M/3.09G [00:01<01:11, 42.7MB/s]
# model.bin:   2% 62.9M/3.09G [00:01<01:10, 42.9MB/s]
# model.bin:   2% 73.4M/3.09G [00:01<01:10, 42.9MB/s]
# model.bin:   3% 83.9M/3.09G [00:01<01:09, 43.2MB/s]
# model.bin:   3% 94.4M/3.09G [00:02<01:08, 43.4MB/s]
# model.bin:   3% 105M/3.09G [00:02<01:09, 43.2MB/s]
# model.bin:   4% 115M/3.09G [00:02<01:08, 43.2MB/s]
# model.bin:   4% 126M/3.09G [00:02<01:08, 43.1MB/s]
# model.bin:   4% 136M/3.09G [00:03<01:08, 43.2MB/s]
# model.bin:   5% 147M/3.09G [00:03<01:08, 43.0MB/s]
# model.bin:   5% 157M/3.09G [00:03<01:07, 43.1MB/s]
# model.bin:   5% 168M/3.09G [00:03<01:09, 42.3MB/s]
# model.bin:   6% 178M/3.09G [00:04<01:08, 42.7MB/s]
# model.bin:   6% 189M/3.09G [00:04<01:07, 42.9MB/s]
# model.bin:   6% 199M/3.09G [00:04<01:07, 42.9MB/s]
# model.bin:   7% 210M/3.09G [00:04<01:06, 43.1MB/s]
# model.bin:  92% 2.85G/3.09G [01:07<00:05, 43.3MB/s]
# model.bin:  93% 2.86G/3.09G [01:08<00:05, 43.5MB/s]
# model.bin:  93% 2.87G/3.09G [01:08<00:04, 43.5MB/s]
# model.bin:  93% 2.88G/3.09G [01:08<00:04, 43.3MB/s]
# model.bin:  94% 2.89G/3.09G [01:08<00:04, 43.3MB/s]
# model.bin:  94% 2.90G/3.09G [01:09<00:04, 43.3MB/s]
# model.bin:  94% 2.92G/3.09G [01:09<00:04, 43.0MB/s]
# model.bin:  95% 2.93G/3.09G [01:09<00:03, 42.8MB/s]
# model.bin:  95% 2.94G/3.09G [01:09<00:03, 42.9MB/s]
# model.bin:  95% 2.95G/3.09G [01:10<00:03, 42.9MB/s]
# model.bin:  96% 2.96G/3.09G [01:10<00:03, 43.1MB/s]
# model.bin:  96% 2.97G/3.09G [01:10<00:02, 43.2MB/s]
# model.bin:  96% 2.98G/3.09G [01:10<00:02, 43.3MB/s]
# model.bin:  97% 2.99G/3.09G [01:11<00:02, 43.2MB/s]
# model.bin:  97% 3.00G/3.09G [01:11<00:02, 43.4MB/s]
# model.bin:  97% 3.01G/3.09G [01:11<00:01, 43.3MB/s]
# model.bin:  98% 3.02G/3.09G [01:11<00:01, 42.6MB/s]
# model.bin:  98% 3.03G/3.09G [01:12<00:01, 43.0MB/s]
# model.bin:  98% 3.04G/3.09G [01:12<00:01, 43.2MB/s]
# model.bin:  99% 3.05G/3.09G [01:12<00:00, 43.3MB/s]
# model.bin:  99% 3.06G/3.09G [01:12<00:00, 41.4MB/s]
# model.bin: 100% 3.07G/3.09G [01:13<00:00, 42.1MB/s]
# model.bin: 100% 3.08G/3.09G [01:13<00:00, 42.5MB/s]
# model.bin: 100% 3.09G/3.09G [01:13<00:00, 42.1MB/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:02<00:00, 8.76MiB/s]
# Detected language: en (1.00) in first 30s of audio...
# Suppressing numeral and symbol tokens
# ASR: 100% 15/15 [00:04<00:00,  3.08it/s]
# [INFO] >> Aligning...
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100% 360M/360M [00:01<00:00, 257MB/s]
# [INFO] >> Diarizing...
# [INFO] >> Translating...
# Translating: 100% 29/29 [00:03<00:00,  8.16it/s]
# [INFO] >> Text to speech...
# [INFO] >> Content in 'audio' removed.
# [INFO] >> PIPER TTS: ['SPEAKER_00']
#   0% 0/29 [00:00<?, ?it/s]2024-10-27 00:44:10.590936430 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 28 Memcpy nodes are added to the graph torch_jit for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2024-10-27 00:44:10.609471781 [W:onnxruntime:, session_state.cc:1166 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2024-10-27 00:44:10.609498008 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# [INFO] >> 1941年日本袭击珍珠港后，美国宣战，从而将美国拖入第二次世界大战，但仅限于太平洋战区。 >> audio/0.209.ogg
#   3% 1/29 [00:08<04:05,  8.77s/it][INFO] >> 然而，四天后，德国在没有必要的情况下向美国宣战。 >> audio/9.177.ogg
#   7% 2/29 [00:09<01:54,  4.24s/it][INFO] >> 从而将美国带入欧洲战区，结果使德国的处境变得相当困难。 >> audio/14.181.ogg
#  10% 3/29 [00:11<01:13,  2.84s/it][INFO] >> 这就引出了一个问题，为什么？ >> audio/20.436.ogg
#  14% 4/29 [00:16<01:38,  3.96s/it][INFO] >> 为什么德国本可以让美国对付日本，却要向美国宣战？ >> audio/22.441.ogg
#  17% 5/29 [00:17<01:10,  2.96s/it][INFO] >> 首先，并不是所有德国人都想向美国宣战。 >> audio/26.933.ogg
#  21% 6/29 [00:19<00:57,  2.49s/it][INFO] >> 德国外交部长约阿希姆冯里宾特洛甫建议不要这样做。 >> audio/31.505.ogg
#  24% 7/29 [00:20<00:44,  2.03s/it][INFO] >> 两国之间的防御条约只要求德国在日本成为侵略受害者的情况下参战。 >> audio/35.609.ogg
#  28% 8/29 [00:21<00:37,  1.78s/it][INFO] >> 他认为，如果找不到在欧洲作战的借口，美国人就会把注意力集中在日本身上。 >> audio/41.794.ogg
#  31% 9/29 [00:23<00:32,  1.60s/it][INFO] >> 从而停止向英国和苏联运送用于太平洋的物资。 >> audio/46.138.ogg
#  34% 10/29 [00:24<00:29,  1.54s/it][INFO] >> 因此，德国领导人（特别是一位德国领导人）宣战的第一个原因是，他认为美国在欧洲作战是不可避免的。 >> audio/50.663.ogg
#  38% 11/29 [00:25<00:26,  1.49s/it][INFO] >> 此时美国已经在向德国的敌人提供补给，而华盛顿的欧洲战争计划在此之前不久也被泄露。 >> audio/57.85.ogg
#  41% 12/29 [00:27<00:24,  1.44s/it][INFO] >> 因此，他们决定，最好是主动宣战并保持主动，而不是等待美国人选择时机。 >> audio/64.333.ogg
#  45% 13/29 [00:28<00:22,  1.43s/it][INFO] >> 第二个原因是希望日本会做出回应。 >> audio/70.236.ogg
#  48% 14/29 [00:30<00:22,  1.50s/it][INFO] >> 日本面临着一个非常强大的敌人，因此德国，我想还有意大利的帮助将有助于分散美国的注意力。 >> audio/73.1.ogg
# 2024-10-27 00:44:35.547888877 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# Traceback (most recent call last):
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 851, in segments_vits_onnx_tts
#     speech_output = synthesize_text_to_audio_np_array(
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 798, in synthesize_text_to_audio_np_array
#     for audio_bytes in audio_stream:
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 123, in synthesize_stream_raw
#     yield self.synthesize_ids_to_raw(
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 166, in synthesize_ids_to_raw
#     audio = self.session.run(
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 220, in run
#     return self._sess.run(output_names, input_feed, run_options)
# onnxruntime.capi.onnxruntime_pybind11_state.RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [ERROR] >> Error: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [WARNING] >> TTS auxiliary will be utilized rather than TTS: zh_CN-huayan-medium VITS-onnx
#  52% 15/29 [00:31<00:18,  1.30s/it][INFO] >> 因此，柏林期望日本会通过向苏联宣战来报复他们。 >> audio/80.752.ogg
#  55% 16/29 [00:32<00:18,  1.41s/it][INFO] >> 问题在于日本人对与苏联作战毫无兴趣。 >> audio/85.324.ogg
# 2024-10-27 00:44:38.028344223 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# Traceback (most recent call last):
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 851, in segments_vits_onnx_tts
#     speech_output = synthesize_text_to_audio_np_array(
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 798, in synthesize_text_to_audio_np_array
#     for audio_bytes in audio_stream:
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 123, in synthesize_stream_raw
#     yield self.synthesize_ids_to_raw(
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 166, in synthesize_ids_to_raw
#     audio = self.session.run(
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 220, in run
#     return self._sess.run(output_names, input_feed, run_options)
# onnxruntime.capi.onnxruntime_pybind11_state.RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [ERROR] >> Error: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [WARNING] >> TTS auxiliary will be utilized rather than TTS: zh_CN-huayan-medium VITS-onnx
#  59% 17/29 [00:33<00:14,  1.18s/it][INFO] >> 第三个原因是德国领导人认为向美国宣战将迫使欧洲中立国选边站。 >> audio/89.153.ogg
#  62% 18/29 [00:34<00:11,  1.05s/it][INFO] >> 土耳其、瑞典和西班牙等国与美国有贸易往来，与德国开战意味着它们的贸易可能会下降。 >> audio/95.359.ogg
#  66% 19/29 [00:35<00:11,  1.13s/it][INFO] >> 希望这些国家随后会转向德国及其盟友以满足那里的任何需求，然后他们可能会被迫加入战争。 >> audio/101.084.ogg
#  69% 20/29 [00:36<00:10,  1.20s/it][INFO] >> 这不是一个合乎逻辑的计划，但这是由于第四个原因。 >> audio/108.193.ogg
#  72% 21/29 [00:38<00:10,  1.35s/it][INFO] >> 德国人认为他们即将获胜。 >> audio/111.758.ogg
#  76% 22/29 [00:44<00:18,  2.62s/it][INFO] >> 从战争一开始，德国就处于连胜的状态，自从那年早些时候入侵苏联以来，德国军队一直推进到这里。 >> audio/113.783.ogg
#  79% 23/29 [00:45<00:13,  2.26s/it][INFO] >> 人们认为苏联距离彻底崩溃仅有几个月的时间，届时这些军队可以调动以增援西方，抵御美国入侵。 >> audio/121.34.ogg
#  83% 24/29 [00:46<00:09,  2.00s/it][INFO] >> 如果你想知道，意大利人也向美国宣战，因为他们不想惹恼德国人。 >> audio/128.969.ogg
#  86% 25/29 [00:48<00:06,  1.75s/it][INFO] >> 如你所知，这个决定并不是最好的，因为罗斯福认为打败德国是当务之急，这对他们来说当然是个坏消息。 >> audio/133.999.ogg
#  90% 26/29 [00:49<00:04,  1.64s/it][INFO] >> 希望你喜欢这一集，特别感谢我的赞助人 James Bizonette、Kelly Moneymaker、Skye Chappell、Katoitska、Yuduan Wang、Anthony Beckett、YN Hockey、Marcus Arsner、Captain Psydog、Gustav Swan、The McWhopper、Alex Schwinn、Marvin Casau、 >> audio/141.573.ogg
#  93% 27/29 [00:50<00:03,  1.57s/it][INFO] >> Winston Kaywood、Shuenin、Andy McGeehy、A.F. >> audio/155.489.ogg
#  97% 28/29 [01:02<00:04,  4.69s/it][INFO] >> Firefly、Spinning Three Plates、Spencer Lightfoot、Kimu Nyun、Maggie Patskowski、Remco Huisman、Cop​​per Tone、Jim Strunberg、Calling Dr. Howard、Dr. Fine、Dr. Howard、Charles I、Miss Izzet 和 Words About Books 播客。 >> audio/158.05.ogg
# 2024-10-27 00:45:14.604397240 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# Traceback (most recent call last):
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 851, in segments_vits_onnx_tts
#     speech_output = synthesize_text_to_audio_np_array(
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 798, in synthesize_text_to_audio_np_array
#     for audio_bytes in audio_stream:
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 123, in synthesize_stream_raw
#     yield self.synthesize_ids_to_raw(
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 166, in synthesize_ids_to_raw
#     audio = self.session.run(
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 220, in run
#     return self._sess.run(output_names, input_feed, run_options)
# onnxruntime.capi.onnxruntime_pybind11_state.RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [ERROR] >> Error: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [WARNING] >> TTS auxiliary will be utilized rather than TTS: zh_CN-huayan-medium VITS-onnx
# 100% 29/29 [01:11<00:00,  2.45s/it]
# [INFO] >> Apply acceleration
# [INFO] >> Content in 'audio2/audio/' removed.
# 29it [00:02, 10.46it/s]
# [INFO] >> Voice Imitation...
# [INFO] >> FreeVC only uses one segment.
# [INFO] >> FreeVC preprocessor...
# [INFO] >> Content in 'processed' removed.
# [INFO] >> Processing segment: 9.177, 13.901, SPEAKER_00, 4.724, 然而，四天后，德国在没有必要的情况下向美国宣战。
# [INFO] >> Vocal Track Isolation and Voiceless Track Separation...
# 100% 2/2 [00:01<00:00,  1.88it/s]
# 100% 2/2 [00:00<00:00,  3.71it/s]
# [INFO] >> Main Voice Separation from Supporting Vocals...
# 100% 2/2 [00:00<00:00,  4.69it/s]
# 100% 2/2 [00:00<00:00,  4.97it/s]
# [INFO] >> ./processed/SPEAKER_00audio_5YgGd0ls_^3_^kWpG4/9.177.wav
# [INFO] >> FreeVC loading model...
#  > Downloading model to /root/.local/share/tts/voice_conversion_models--multilingual--vctk--freevc24
#  > Model's license - MIT
#  > Check https://choosealicense.com/licenses/mit/ for more info.
#  > Using model: freevc
#  > Loading pretrained speaker encoder model ...
# Loaded the voice encoder model on cuda in 1.86 seconds.
#  > Downloading WavLM model to /root/.local/share/tts/wavlm/WavLM-Large.pt ...
# [INFO] >> FreeVC process:
# Progress: 100% 29/29 [00:16<00:00,  1.79it/s]
# [INFO] >> Creating final translated video...
# 29it [00:05,  5.02it/s]
# [INFO] >> Done: /content/SoniTranslate/outputs/Why did Germany declare war on America during WW2_ Short Animated Documentary__zh.mp4
# [INFO] >> Content in 'outputs' removed.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 495, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 235, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1627, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1173, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 690, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/SoniTranslate/app_rvc.py", line 365, in batch_multilingual_media_conversion
#     output_file = self.multilingual_media_conversion(
#   File "/content/SoniTranslate/app_rvc.py", line 544, in multilingual_media_conversion
#     raise ValueError(
# ValueError: Specifify a media or SRT file in advanced settings
# [INFO] >> Content in 'outputs' removed.
# [INFO] >> Cache flushed
# [INFO] >> Processing video...
# [INFO] >> Video codec: h264
# [INFO] >> Process video...
# [INFO] >> Process audio...
# [INFO] >> Transcribing...
# No language specified, language will be first be detected for each audio file (increases inference time).
# Detected language: en (1.00) in first 30s of audio...
# Suppressing numeral and symbol tokens
# ASR: 100% 27/27 [00:11<00:00,  2.43it/s]
# [INFO] >> Aligning...
# [INFO] >> Diarizing...
# [INFO] >> Translating...
# Translating: 100% 44/44 [00:03<00:00, 11.31it/s]
# [INFO] >> Text to speech...
# [INFO] >> Content in 'audio' removed.
# [INFO] >> PIPER TTS: ['SPEAKER_00']
#   0% 0/44 [00:00<?, ?it/s]Wrong size (expected=4822, actual=5234) for /content/SoniTranslate/PIPER_MODELS/zh_CN-huayan-medium.onnx.json
# 2024-10-27 00:53:43.834321312 [W:onnxruntime:, transformer_memcpy.cc:74 ApplyImpl] 28 Memcpy nodes are added to the graph torch_jit for CUDAExecutionProvider. It might have negative impact on performance (including unable to run CUDA graph). Set session_options.log_severity_level=1 to see the detail logs before this message.
# 2024-10-27 00:53:43.851486469 [W:onnxruntime:, session_state.cc:1166 VerifyEachNodeIsAssignedToAnEp] Some nodes were not assigned to the preferred execution providers which may or may not have an negative impact on performance. e.g. ORT explicitly assigns shape related ops to CPU to improve perf.
# 2024-10-27 00:53:43.851511094 [W:onnxruntime:, session_state.cc:1168 VerifyEachNodeIsAssignedToAnEp] Rerunning with verbose output on a non-minimal build will show node assignments.
# [INFO] >> 作为一个在路易斯安那州河口长大的孩子，我最害怕的就是密西西比河会冲走我的州。 >> audio/4.574.ogg
#   2% 1/44 [00:04<02:53,  4.04s/it][INFO] >> 由于海岸侵蚀，路易斯安那州每隔 100 分钟就会失去一个足球场大小的土地。 >> audio/16.601.ogg
#   5% 2/44 [00:05<01:44,  2.49s/it][INFO] >> 对一个孩子来说，这是一个难以想象的巨大数字。 >> audio/24.71.ogg
#   7% 3/44 [00:07<01:31,  2.23s/it][INFO] >> 但在我的一生中，我们已经失去了超过六百平方英里的土地。 >> audio/27.999.ogg
#   9% 4/44 [00:08<01:13,  1.84s/it][INFO] >> 这比纽约市、旧金山、华盛顿特区和亚特兰大的面积总和还要大。 >> audio/33.817.ogg
#  11% 5/44 [00:09<01:02,  1.61s/it][INFO] >> 这是由于海平面上升、海水变暖、风暴日益猛烈以及石油和天然气工业的勘探造成的。 >> audio/42.352.ogg
#  14% 6/44 [00:11<00:58,  1.54s/it][INFO] >> 在我读工程专业的最后一个完整学期，为了两块钱的钱，我和我的男朋友为路易斯安那州缺乏玻璃回收而感到遗憾。 >> audio/51.877.ogg
#  16% 7/44 [00:12<00:57,  1.56s/it][INFO] >> 我的州每年要填埋大约两亿九千五百万磅玻璃。 >> audio/63.601.ogg
#  18% 8/44 [00:14<00:58,  1.62s/it][INFO] >> 我们刚喝完的瓶子很可能会被送进垃圾填埋场。 >> audio/69.544.ogg
#  20% 9/44 [00:16<00:54,  1.56s/it][INFO] >> 这感觉完全是浪费。 >> audio/73.465.ogg
#  23% 10/44 [00:28<02:44,  4.82s/it][INFO] >> 我们想弄清楚如何回收所有这些玻璃。 >> audio/75.657.ogg
#  25% 11/44 [00:29<02:07,  3.86s/it][INFO] >> 第二天，我们快速谷歌搜索了一下才想起玻璃来自沙子，而沙子是一种越来越有限的资源。 >> audio/80.561.ogg
#  27% 12/44 [00:31<01:41,  3.18s/it][INFO] >> 顺便说一下，我们还了解了沙子的所有用途，包括牙膏。 >> audio/90.831.ogg
#  30% 13/44 [00:32<01:20,  2.60s/it][INFO] >> 我们找到的最后一块拼图是一台小型、人形大小的机器，它可以一次将一个瓶子压碎成沙子，我们立即行动起来。 >> audio/96.32.ogg
#  32% 14/44 [00:34<01:08,  2.29s/it][INFO] >> 发起了 GoFundMe 活动，并在兄弟会后院进行了试点项目。 >> audio/104.855.ogg
#  34% 15/44 [00:35<00:56,  1.95s/it][INFO] >> 现在，您可能会想，两个大学生究竟如何能够解决这些问题？ >> audio/112.802.ogg
#  36% 16/44 [00:36<00:48,  1.72s/it][INFO] >> 这是有道理的。 >> audio/119.646.ogg
#  39% 17/44 [01:01<03:52,  8.61s/it][INFO] >> 很多人都告诉过我们同样的事情。 >> audio/121.006.ogg
#  41% 18/44 [01:06<03:21,  7.74s/it][INFO] >> 但我们没有听，因为我们知道无论我们造成的影响多小，都是值得的。 >> audio/124.008.ogg
#  43% 19/44 [01:08<02:25,  5.84s/it][INFO] >> 感觉我们可以通过一个解决方案缓解两个问题。 >> audio/130.902.ogg
#  45% 20/44 [01:10<01:51,  4.63s/it][INFO] >> 将原本要填埋的玻璃重新转化为沙子，并用于全州的修复项目。 >> audio/134.546.ogg
#  48% 21/44 [01:11<01:22,  3.60s/it][INFO] >> 很简单，对吧？ >> audio/141.953.ogg
#  50% 22/44 [01:32<03:14,  8.83s/it][INFO] >> 但我们没有听从仇恨者的意见，这也是我们将公司命名为 Glass Half Full 的原因。 >> audio/145.148.ogg
#  52% 23/44 [01:33<02:18,  6.59s/it][INFO] >> 但这种“半杯空”的心态实际上可能是我们今天面临的最大威胁之一。 >> audio/151.935.ogg
#  55% 24/44 [01:34<01:39,  4.98s/it][INFO] >> 因为气候冷漠可能是新的气候否认论，这意味着对我们环境的最大威胁可能不再是否认我们在气候变化中的作用的人，而是否认我们实际上可以有所作为的人。 >> audio/158.356.ogg
#  57% 25/44 [01:36<01:17,  4.05s/it][INFO] >> 现在，气候变化就在我们眼前发生。 >> audio/174.827.ogg
#  59% 26/44 [01:42<01:21,  4.52s/it][INFO] >> 这太可怕了。 >> audio/177.552.ogg
#  61% 27/44 [02:07<02:59, 10.58s/it][INFO] >> 我亲眼目睹了像艾达这样迅速加剧的飓风的严重性。 >> audio/178.735.ogg
#  64% 28/44 [02:08<02:04,  7.78s/it][INFO] >> 但恐惧、厄运和悲观往往无济于事，而希望与行动相结合可以成为实现变革的最有力工具之一。 >> audio/185.111.ogg
#  66% 29/44 [02:10<01:28,  5.92s/it][INFO] >> 自从四年多前那个深夜喝酒后萌生的念头以来，我们已经能够将超过 800 万磅的玻璃从垃圾填埋场转移出去。 >> audio/201.764.ogg
#  68% 30/44 [02:11<01:04,  4.62s/it][INFO] >> 谢谢。 >> audio/210.069.ogg
#  70% 31/44 [02:15<00:55,  4.28s/it][INFO] >> 我们很快就摆脱了那台小机器的束缚，并在此过程中进行了许多升级。 >> audio/214.622.ogg
#  73% 32/44 [02:15<00:38,  3.23s/it][INFO] >> 我们继续与墨西哥湾南部 50 多位科学家和工程师合作，他们帮助我了解这是不是好闻的泥浆。 >> audio/220.563.ogg
#  75% 33/44 [02:17<00:29,  2.69s/it][INFO] >> 而且还了解了沙子与我们地区的植物、动物甚至真菌之间的相互作用。 >> audio/230.183.ogg
# 2024-10-27 00:55:59.240043730 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# Traceback (most recent call last):
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 851, in segments_vits_onnx_tts
#     speech_output = synthesize_text_to_audio_np_array(
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 798, in synthesize_text_to_audio_np_array
#     for audio_bytes in audio_stream:
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 123, in synthesize_stream_raw
#     yield self.synthesize_ids_to_raw(
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 166, in synthesize_ids_to_raw
#     audio = self.session.run(
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 220, in run
#     return self._sess.run(output_names, input_feed, run_options)
# onnxruntime.capi.onnxruntime_pybind11_state.RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [ERROR] >> Error: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [WARNING] >> TTS auxiliary will be utilized rather than TTS: zh_CN-huayan-medium VITS-onnx
#  77% 34/44 [02:18<00:21,  2.11s/it][INFO] >> 我们还回答了一些难题，以及诸如你真的可以在玻璃制成的沙子上行走吗？ >> audio/237.813.ogg
# 2024-10-27 00:55:59.980759085 [E:onnxruntime:, sequential_executor.cc:516 ExecuteKernel] Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# Traceback (most recent call last):
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 851, in segments_vits_onnx_tts
#     speech_output = synthesize_text_to_audio_np_array(
#   File "/content/SoniTranslate/soni_translate/text_to_speech.py", line 798, in synthesize_text_to_audio_np_array
#     for audio_bytes in audio_stream:
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 123, in synthesize_stream_raw
#     yield self.synthesize_ids_to_raw(
#   File "/usr/local/lib/python3.10/dist-packages/piper/voice.py", line 166, in synthesize_ids_to_raw
#     audio = self.session.run(
#   File "/usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py", line 220, in run
#     return self._sess.run(output_names, input_feed, run_options)
# onnxruntime.capi.onnxruntime_pybind11_state.RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [ERROR] >> Error: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Reshape node. Name:'/Reshape_1' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/tensor/reshape_helper.h:28 onnxruntime::ReshapeHelper::ReshapeHelper(const onnxruntime::TensorShape&, onnxruntime::TensorShapeVector&, bool) i < input_shape.NumDimensions() was false. The dimension with value zero exceeds the dimension size of the input tensor.
#
# [WARNING] >> TTS auxiliary will be utilized rather than TTS: zh_CN-huayan-medium VITS-onnx
#  80% 35/44 [02:18<00:15,  1.69s/it][INFO] >> 为了回答这个问题，我在网上进行了探索。 >> audio/246.464.ogg
#  82% 36/44 [02:20<00:14,  1.76s/it][INFO] >> 再过几个月，我们将启用新设施，回收每年进入垃圾填埋场的 2.95 亿磅玻璃。 >> audio/252.031.ogg
#  84% 37/44 [02:22<00:11,  1.70s/it][INFO] >> 通过使用可生物降解的沙袋和本地沼泽草，我们已经恢复了沿海地区数千平方米的土地，将开放水域重新变成了生机勃勃的湿地。 >> audio/269.284.ogg
#  86% 38/44 [02:23<00:10,  1.71s/it][INFO] >> 但迄今为止，我们成功的关键不在于我们一开始就拥有所有答案，也不在于我们拥有大量资金来尝试这件事。 >> audio/288.766.ogg
#  89% 39/44 [02:25<00:08,  1.66s/it][INFO] >> 关键在于我们只是开始了，然后继续前进。 >> audio/296.275.ogg
#  91% 40/44 [02:27<00:06,  1.66s/it][INFO] >> 在某种程度上，我们作为个人可以推动变革的信念战胜​​了我们的疑虑。 >> audio/300.66.ogg
#  93% 41/44 [02:28<00:04,  1.53s/it][INFO] >> 对我们来说，找到一种方式来解决比我们自己更大的问题意味着迈出第一步。 >> audio/307.051.ogg
#  95% 42/44 [02:29<00:02,  1.45s/it][INFO] >> 对我们来说，这是在曾经宏伟但正在侵蚀的沼泽中踏出第一步。 >> audio/314.96.ogg
#  98% 43/44 [02:30<00:01,  1.25s/it][INFO] >> 谢谢大家。 >> audio/322.149.ogg
# 100% 44/44 [02:51<00:00,  3.90s/it]
# [INFO] >> Apply acceleration
# [INFO] >> Content in 'audio2/audio/' removed.
# 44it [00:03, 14.31it/s]
# [INFO] >> Voice Imitation...
# [INFO] >> FreeVC only uses one segment.
# [INFO] >> FreeVC preprocessor...
# [INFO] >> Content in 'processed' removed.
# [INFO] >> Processing segment: 16.601, 23.433, SPEAKER_00, 6.832000000000001, 由于海岸侵蚀，路易斯安那州每隔 100 分钟就会失去一个足球场大小的土地。
# [INFO] >> Vocal Track Isolation and Voiceless Track Separation...
# 100% 2/2 [00:00<00:00,  2.51it/s]
# 100% 2/2 [00:00<00:00,  2.52it/s]
# [INFO] >> Main Voice Separation from Supporting Vocals...
# 100% 2/2 [00:00<00:00,  4.42it/s]
# 100% 2/2 [00:00<00:00,  4.60it/s]
# [INFO] >> Vocal Clarity Enhancement through De-Reverberation...
# 100% 2/2 [00:01<00:00,  1.52it/s]
# 100% 2/2 [00:01<00:00,  1.67it/s]
# [INFO] >> ./processed/SPEAKER_00audio_uaiWnjzHTpJkGSXv/16.601.wav
# [INFO] >> FreeVC loading model...
#  > voice_conversion_models/multilingual/vctk/freevc24 is already downloaded.
#  > Using model: freevc
#  > Loading pretrained speaker encoder model ...
# Loaded the voice encoder model on cuda in 0.12 seconds.
# [INFO] >> FreeVC process:
# Progress: 100% 44/44 [00:21<00:00,  2.07it/s]
# [INFO] >> Creating final translated video...
# 44it [00:09,  4.50it/s]
# [INFO] >> Done: /content/SoniTranslate/outputs/Your Empty Wine Bottle Could Help Rebuild Coastlines _ Franziska Trautmann _ TED__zh.mp4

# %% [markdown]
# Open the `public URL` when it appears
